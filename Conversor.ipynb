# %%
# !pip install img2wav

# %%
# !img2wav -o 'Tiara.wav' 'Tiara.jpeg' -s 16000 -d 1 -b 14000
# Out:
# [*] Writing wav file: /content/drive/MyDrive/Colab Notebooks/Andulador/Tiara.wav
# [*]   Center frequency: 2750hz
# [*]   Bandwidth       : 14000hz
# [*]   Sample rate     : 16000hz
# [*]   Delay           : 1ms
# [*] Processing: /content/drive/MyDrive/Colab Notebooks/Andulador/Tiara.jpeg
# [+] Done
